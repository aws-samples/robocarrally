# %%
# Create a new car using the library CLI
# !donkey createcar --path /home/ec2-user/SageMaker/d2
# Out:
# using donkey v2.2.4 ...
# Creating car folder: /home/ec2-user/SageMaker/d2
# making dir  /home/ec2-user/SageMaker/d2
# Creating data & model folders.
# making dir  /home/ec2-user/SageMaker/d2/models
# making dir  /home/ec2-user/SageMaker/d2/data
# making dir  /home/ec2-user/SageMaker/d2/logs
# Copying car application template: donkey2
# Copying car config defaults. Adjust these before starting your car.
# Donkey setup complete.

# %%
# Copy from zipped data from S3 to the Notebook instance. 
# Be sure to update 'your_bucket_name' with your S3 bucket as well as the tarball you named in Step 8. 
# !aws s3 cp s3://your_bucket_name/tub_name.tar.gz /home/ec2-user/SageMaker/d2/data/
# Out:
# download: s3://escalona-sagemaker/robocartrainingdata/tub_13_19-03-07.tar.gz to d2/data/tub_13_19-03-07.tar.gz

# %%
# Unzip the data (remeber to update with your tarball name)
# !tar -xzvf ~/SageMaker/d2/data/tub_name.tar.gz
# Out:
# home/pi/d2/data/tub_13_19-03-07/
# home/pi/d2/data/tub_13_19-03-07/record_165.json
# home/pi/d2/data/tub_13_19-03-07/238_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/408_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/602_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/record_855.json
# home/pi/d2/data/tub_13_19-03-07/453_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/record_704.json
# home/pi/d2/data/tub_13_19-03-07/432_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/806_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/record_164.json
# home/pi/d2/data/tub_13_19-03-07/393_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/212_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/883_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/600_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/894_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/848_cam-image_array_.jpg
# home/pi/d2/data/tub_13_19-03-07/record_805.json
# ...

# %%
# Next, you will head back to the terminal and run the training script. 
# See step 10c instructions for the complete command.
